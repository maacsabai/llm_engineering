# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/perplexity-ai/r1-1776',
#  '/deepseek-ai/DeepSeek-R1',
#  '/microsoft/OmniParser-v2.0',
#  '/stepfun-ai/Step-Audio-Chat',
#  '/stepfun-ai/stepvideo-t2v',
#  '/models',
#  '/spaces/nanotron/ultrascale-playbook',
#  '/spaces/lllyasviel/LuminaBrush',
#  '/spaces/microsoft/OmniParser-v2',
#  '/spaces/black-forest-labs/FLUX.1-dev',
#  '/spaces/m-ric/open_Deep-Research',
#  '/spaces',
#  '/datasets/Congliu/Chinese-DeepSeek-R1-Distill-data-110k',
#  '/datasets/facebook/natural_reasoning',
#  '/datasets/open-r1/OpenR1-Math-220k',
#  '/datasets/open-thoughts/OpenThoughts-114k',
#  '/datasets/SakanaAI/AI-CUDA-Engineer-Archive',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'discussion forum', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'homepage', 'url': 'https://huggingface.co/'}, {'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# perplexity-ai/r1-1776
# Updated
# 3 days ago
# •
# 7.03k
# •
# 1.38k
# deepseek-ai/DeepSeek-R1
# Updated
# 13 days ago
# •
# 4.4M
# •
# 9.9k
# microsoft/OmniParser-v2.0
# Updated
# 4 days ago
# •
# 4.2k
# •
# 834
# stepfun-ai/Step-Audio-Chat
# Updated
# 5 days ago
# •
# 609
# •
# 335
# stepfun-ai/stepvideo-t2v
# Updated
# 3 days ago
# •
# 944
# •
# 281
# Browse 1M+ models
# Spaces
# Running
# 1.25k
# 1.25k
# The Ultra-Scale Playbook
# 🌌
# The ultimate guide to training LLM on large GPU Clusters
# Running
# on
# Zero
# 645
# 645
# LuminaBrush
# 📈
# Execute environment script
# Running
# on
# Zero
# 271
# 271
# OmniParser V2
# 🏢
# OmniParser, turn your LLM into GUI agent
# Running
# on
# Zero
# 7.34k
# 7.34k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# Running
# on
# CPU Upgrade
# 518
# 518
# Open Deep-Research
# 🏆
# OpenAI's Deep Research, but open
# Browse 400k+ applications
# Datasets
# Congliu/Chinese-DeepSeek-R1-Distill-data-110k
# Updated
# 1 day ago
# •
# 1.95k
# •
# 301
# facebook/natural_reasoning
# Updated
# 1 day ago
# •
# 804
# •
# 134
# open-r1/OpenR1-Math-220k
# Updated
# 4 days ago
# •
# 18.3k
# •
# 387
# open-thoughts/OpenThoughts-114k
# Updated
# 2 days ago
# •
# 101k
# •
# 576
# SakanaAI/AI-CUDA-Engineer-Archive
# Updated
# 2 days ago
# •
# 4.62k
# •
# 75
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 389 models
# •
# 2.39k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.68k followers
# Amazon Web Services
# company
# •
# 20 models
# •
# 2.75k followers
# Google
# company
# •
# 959 models
# •
# 8.04k followers
# Intel
# company
# •
# 218 models
# •
# 2.27k followers
# Microsoft
# company
# •
# 356 models
# •
# 8.98k followers
# Grammarly
# company
# •
# 10 models
# •
# 126 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 241 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 139,937
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 27,625
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,121
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,356
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,399
# Fast tokenizers optimized for research & production
# TRL
# 11,885
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,020
# State-of-the-art ML running directly in your browser
# smolagents
# 11,436
# Smol library to build great agents in Python
# PEFT
# 17,423
# Parameter-efficient finetuning for large language models
# Datasets
# 19,667
# Access & share datasets for any ML tasks
# Text Generation Inference
# 9,787
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,368
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# homepage
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# perplexity-ai/r1-1776
# Updated
# 3 days ago
# •
# 7.03k
# •
# 1.38k
# deepseek-ai/DeepSeek-R1
# Updated
# 13 days ago
# •
# 4.4M
# •
# 9.9k
# microsoft/OmniParser-v2.0
# Updated
# 4 days ago
# •
# 4.2k
# •
# 834
# stepfun-ai/Step-Audio-Chat
# Updated
# 5 days ago
# •
# 609
# •
# 335
# stepfun-ai/stepvideo-t2v
# Updated
# 3 days ago
# •
# 944
# •
# 281
# Browse 1M+ models
# Spaces
# Running
# 1.25k
# 1.25k
# The Ultra-Scale Playbook
# 🌌
# The ultimate guide to training LLM on large GPU Clusters
# Running
# on
# Zero
# 645
# 645
# LuminaBrush
# 📈
# Execute environment script
# Running
# on
# Zero
# 271
# 271
# OmniParser V2
# 🏢
# OmniParser, turn your LLM into GUI agent
# Running
# on
# Zero
# 7.34k
# 7.34k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# Running
# on
# CPU Upgrade
# 518
# 518
# Open Deep-Research
# 🏆
# OpenAI's Deep Research, but open
# Browse 400k+ applications
# Datasets
# Congliu/Chinese-DeepSeek-R1-Distill-data-110k
# Updated
# 1 day ago
# •
# 1.95k
# •
# 301
# facebook/natural_reasoning
# Updated
# 1 day ago
# •
# 804
# •
# 134
# open-r1/OpenR1-Math-220k
# Updated
# 4 days ago
# •
# 18.3k
# •
# 387
# open-thoughts/OpenThoughts-114k
# Updated
# 2 days ago
# •
# 101k
# •
# 576
# SakanaAI/AI-CUDA-Engineer-Archive
# Updated
# 2 days ago
# •
# 4.62k
# •
# 75
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 389 models
# •
# 2.39k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.68k followers
# Amazon Web Services
# company
# •
# 20 models
# •
# 2.75k followers
# Google
# company
# •
# 959 models
# •
# 8.04k followers
# Intel
# company
# •
# 218 models
# •
# 2.27k followers
# Microsoft
# company
# •
# 356 models
# •
# 8.98k followers
# Grammarly
# company
# •
# 10 models
# •
# 126 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 241 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 139,937
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 27,625
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,121
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,356
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,399
# Fast tokenizers optimized for research & production
# TRL
# 11,885
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,020
# State-of-the-art ML running directly in your browser
# smolagents
# 11,436
# Smol library to build great agents in Python
# PEFT
# 17,423
# Parameter-efficient finetuning for large language models
# Datasets
# 19,667
# Access & share datasets for any ML tasks
# Text Generation Inference
# 9,787
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,368
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 21,395
# AI & ML interests
# The AI community building the future.
# Recent Activity
# hlky
# updated
# a dataset
# about 1 hour ago
# huggingface/documentation-images
# hlky
# new
# activity
# about 1 hour ago
# huggingface/documentation-images:
# remote vae blog post
# hlky
# new
# activity
# about 1 hour ago
# huggingface/documentation-images:
# remote vae blog post
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 34
# Team members
# 210
# +176
# +163
# +142
# +132
# +112
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 286k
# •
# 38
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 15.8M
# •
# •
# 621
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 1.04M
# •
# •
# 168
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 7.7M
# •
# •
# 691
# spaces
# 23
# Sort:
# 		Recently updated
# pinned
# Running
# 64
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 92
# Inference Playground
# 🔋
# Generate responses to chat messages
# huggingface
# 2 days ago
# Running
# 528
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Running
# 211
# paper-central
# ⚡
# Explore and manage research papers
# huggingface
# Dec 13, 2024
# Running
# on
# TPU v5e
# 8
# Keras Chatbot Battle
# 💬
# Interact with multiple chatbots simultaneously
# huggingface
# Dec 5, 2024
# Running
# 104
# Modelcard Creator
# ⚡
# Create and upload a Hugging Face model card
# huggingface
# Oct 26, 2024
# Expand 23
# 							spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Dec 9, 2024
# •
# 35
# •
# 1
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 3k
# •
# •
# 56
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 64
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 56.6k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 280
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 26.4k
# •
# 5
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 3.74k
# •
# 18
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 69
# •
# 4
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 34.9k
# •
# 76
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand 16
# 							models
# datasets
# 39
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 7 hours ago
# •
# 50
# •
# 4.43M
# •
# 49
# huggingface/gemini-results-2025-02-21
# Viewer
# •
# Updated
# about 8 hours ago
# •
# 12
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 1 day ago
# •
# 1.57k
# •
# 3.19k
# •
# 16
# huggingface/gemini-results-2025-02-20
# Viewer
# •
# Updated
# 1 day ago
# •
# 29
# •
# 5
# huggingface/gemini-results-2025-02-19
# Viewer
# •
# Updated
# 2 days ago
# •
# 30
# •
# 15
# huggingface/gemini-results-2025-02-18
# Viewer
# •
# Updated
# 3 days ago
# •
# 38
# •
# 19
# huggingface/gemini-results-2025-02-17
# Viewer
# •
# Updated
# 4 days ago
# •
# 23
# •
# 74
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# 5 days ago
# •
# 130
# •
# 73
# huggingface/gemini-results-new-cs-papers-2025-02-11-0-100-updated
# Viewer
# •
# Updated
# 5 days ago
# •
# 100
# •
# 72
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 7 days ago
# •
# 66
# •
# 465
# •
# 5
# Expand 39
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 285 models
# •
# 16.3k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 281 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 181 followers
# Writer
# Enterprise
# company
# •
# 17 models
# •
# 241 followers
# Xsolla
# Enterprise
# company
# •
# 99 followers
# Fidelity Investments
# Enterprise
# company
# •
# 124 followers
# Mistral AI_
# Enterprise
# company
# •
# 23 models
# •
# 5.53k followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 65 models
# •
# 1.22k followers
# Chegg Inc
# Enterprise
# company
# •
# 82 followers
# Nutanix
# Enterprise
# company
# •
# 262 models
# •
# 59 followers
# creditkarma
# Enterprise
# company
# •
# 47 followers
# Liberty Mutual
# Enterprise
# company
# •
# 43 followers
# StepFun
# Enterprise
# company
# •
# 7 models
# •
# 592 followers
# Ekimetrics
# Enterprise
# company
# •
# 52 followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 28k followers
# AMD
# Enterprise
# company
# •
# 88 models
# •
# 1.31k followers
# AI at Meta
# Enterprise
# company
# •
# 2.06k models
# •
# 4.68k followers
# Arm
# Enterprise
# company
# •
# 140 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 99 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 392 followers
# Procter & Gamble
# Enterprise
# company
# •
# 70 followers
# IBM Granite
# Enterprise
# company
# •
# 79 models
# •
# 1.07k followers
# Novo Nordisk
# Enterprise
# company
# •
# 50 followers
# Stability AI
# Enterprise
# company
# •
# 99 models
# •
# 16.5k followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 537 followers
# Widn AI
# Enterprise
# company
# •
# 39 followers
# BCG X
# Enterprise
# company
# •
# 33 followers
# Adyen
# Enterprise
# company
# •
# 45 followers
# Shopify
# Enterprise
# company
# •
# 407 followers
# Snowflake
# Enterprise
# company
# •
# 14 models
# •
# 429 followers
# Together
# Enterprise
# company
# •
# 31 models
# •
# 521 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 174 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 125 followers
# Jusbrasil
# Enterprise
# company
# •
# 80 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 122 followers
# Aledade Inc
# Enterprise
# company
# •
# 60 followers
# Virtusa Corporation
# Enterprise
# company
# •
# 60 followers
# Arcee AI
# Enterprise
# company
# •
# 154 models
# •
# 423 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 48 followers
# HiddenLayer
# Enterprise
# company
# •
# 54 followers
# Kakao Corp.
# Enterprise
# company
# •
# 49 followers
# Twelve Labs
# Enterprise
# company
# •
# 35 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Higher rate limits for serverless inference
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# TPU v5e 1x1
# 22 vCPU
# 44 GB
# Google TPU v5e
# 16 GB
# $1.20
# TPU v5e 2x2
# 110 vCPU
# 186 GB
# Google TPU v5e
# 64 GB
# $4.75
# TPU v5e 2x4
# 220 vCPU
# 380 GB
# Google TPU v5e
# 128 GB
# $9.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# HF Inference API
# : Get x20 higher rate limits on HF Serverless API
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# SigLIP 2: A better multilingual vision language encoder
# By
# ariG23498
# February 21, 2025
# •
# 61
# Community Articles
# view all
# Small Language Models (SLMs): A Comprehensive Overview
# By
# jjokah
# •
# about 1 hour ago
# •
# 1
# ROOP Unleashed Final Version: Advanced AI Face Swap Software - One-Click Launch
# By
# daoyou
# •
# about 10 hours ago
# •
# 1
# Open Source AI Agents | Github/Repo List | [2025]
# By
# tegridydev
# •
# 1 day ago
# •
# 9
# Topic 28: What is Mixture-of-Mamba?
# By
# Kseniase
# and 1 other
# •
# 1 day ago
# •
# 2
# Mimicking Consciousness in LLMs: Ascending the Dimensions of Thought with Recurrent Processing
# By
# KnutJaegersberg
# •
# 2 days ago
# 结合Deepseek代码探讨MLA的改进及收益
# By
# Junrulu
# •
# 2 days ago
# •
# 3
# 大模型偏好优化技术：DPO及其变种
# By
# Junrulu
# •
# 2 days ago
# •
# 3
# Grok 3 ai : Best AI model now!
# By
# LLMhacker
# •
# 3 days ago
# •
# 4
# Argunauts Training Phase II: Selfplay Finetuning Line-By-Line
# By
# ggbetz
# •
# 3 days ago
# •
# 2
# Synthetic Face Embeddings: Research Notes and Methodology
# By
# jadechip
# and 1 other
# •
# 3 days ago
# •
# 1
# How to use Sentient’s Dobby-70B
# By
# chrisaubin
# •
# 3 days ago
# Mahjong: Where Grandmas Beat The Best LLMs
# By
# sileixu
# •
# 3 days ago
# •
# 1
# Mixture of Tunable Experts - Behavior Modification of DeepSeek-R1 at Inference Time
# By
# rbrt
# and 4 others
# •
# 4 days ago
# •
# 19
# Argunauts Training Phase I: Continual Pretraining on Synthetic Data
# By
# ggbetz
# •
# 4 days ago
# Best AI Setups for Multi-Agent Workflows in KaibanJS
# By
# darielnoel
# •
# 4 days ago
# 🌁#88: Can DeepSeek Inspire Global Collaboration?
# By
# Kseniase
# •
# 5 days ago
# •
# 3
# Adapter l’intelligence artificielle au créole
# By
# hugohow
# •
# 5 days ago
# •
# 1
# Open-sourcing the Plain English to SQL Pipeline
# By
# ZennyKenny
# •
# 5 days ago
# •
# 1
# Fine-tuning SmolLM with Group Relative Policy Optimization (GRPO) by following the Methodologies
# By
# prithivMLmods
# •
# 5 days ago
# •
# 16
# Nexus Shift: AI Generated Short Story
# By
# Duskfallcrew
# •
# 5 days ago
# SmolVLM2: Bringing Video Understanding to Every Device
# By
# orrzohar
# February 20, 2025
# guest
# •
# 123
# PaliGemma 2 Mix - New Instruction Vision Language Models by Google
# By
# ariG23498
# February 19, 2025
# •
# 50
# Introducing Three New Serverless Inference Providers: Hyperbolic, Nebius AI Studio, and Novita 🔥
# By
# reach-vb
# February 18, 2025
# •
# 86
# Welcome Fireworks.ai on the Hub 🎆
# By
# julien-c
# February 14, 2025
# •
# 51
# Fixing Open LLM Leaderboard with Math-Verify
# By
# hynky
# February 14, 2025
# •
# 24
# 1 Billion Classifications
# By
# derek-thomas
# February 13, 2025
# guest
# •
# 38
# From Chunks to Blocks: Accelerating Uploads and Downloads on the Hub
# By
# jsulz
# February 12, 2025
# •
# 48
# Build awesome datasets for video generation
# By
# hlky
# February 12, 2025
# •
# 25
# The Open Arabic LLM Leaderboard 2
# By
# alielfilali01
# February 10, 2025
# guest
# •
# 25
# Open-source DeepResearch – Freeing our search agents
# By
# m-ric
# February 4, 2025
# •
# 1.07k
# π0 and π0-FAST: Vision-Language-Action Models for General Robot Control
# By
# danaaubakirova
# February 4, 2025
# •
# 106
# DABStep: Data Agent Benchmark for Multi-step Reasoning
# By
# eggie5
# February 4, 2025
# guest
# •
# 49
# The AI tools for Art Newsletter - Issue 1
# By
# linoyts
# January 31, 2025
# •
# 64
# How to deploy and fine-tune DeepSeek models on AWS
# By
# pagezyhf
# January 30, 2025
# •
# 46
# Previous
# 1
# 2
# 3
# ...
# 39
# Next
# Community Articles
# view all
# Small Language Models (SLMs): A Comprehensive Overview
# By
# jjokah
# •
# about 1 hour ago
# •
# 1
# ROOP Unleashed Final Version: Advanced AI Face Swap Software - One-Click Launch
# By
# daoyou
# •
# about 10 hours ago
# •
# 1
# Open Source AI Agents | Github/Repo List | [2025]
# By
# tegridydev
# •
# 1 day ago
# •
# 9
# Topic 28: What is Mixture-of-Mamba?
# By
# Kseniase
# and 1 other
# •
# 1 day ago
# •
# 2
# Mimicking Consciousness in LLMs: Ascending the Dimensions of Thought with Recurrent Processing
# By
# KnutJaegersberg
# •
# 2 days ago
# 结合Deepseek代码探讨MLA的改进及收益
# By
# Junrulu
# •
# 2 days ago
# •
# 3
# 大模型偏好优化技术：DPO及其变种
# By
# Junrulu
# •
# 2 days ago
# •
# 3
# Grok 3 ai : Best AI model now!
# By
# LLMhacker
# •
# 3 days ago
# •
# 4
# Argunauts Training Phase II: Selfplay Finetuning Line-By-Line
# By
# ggbetz
# •
# 3 days ago
# •
# 2
# Synthetic Face Embeddings: Research Notes and Methodology
# By
# jadechip
# and 1 other
# •
# 3 days ago
# •
# 1
# How to use Sentient’s Dobby-70B
# By
# chrisaubin
# •
# 3 days ago
# Mahjong: Where Grandmas Beat The Best LLMs
# By
# sileixu
# •
# 3 days ago
# •
# 1
# Mixture of Tunable Experts - Behavior Modification of DeepSeek-R1 at Inference Time
# By
# rbrt
# and 4 others
# •
# 4 days ago
# •
# 19
# Argunauts Training Phase I: Continual Pretraining on Synthetic Data
# By
# ggbetz
# •
# 4 days ago
# Best AI Setups for Multi-Agent Workflows in KaibanJS
# By
# darielnoel
# •
# 4 days ago
# 🌁#88: Can DeepSeek Inspire Global Collaboration?
# By
# Kseniase
# •
# 5 days ago
# •
# 3
# Adapter l’intelligence artificielle au créole
# By
# hugohow
# •
# 5 days ago
# •
# 1
# Open-sourcing the Plain English to SQL Pipeline
# By
# ZennyKenny
# •
# 5 days ago
# •
# 1
# Fine-tuning SmolLM with Group Relative Policy Optimization (GRPO) by following the Methodologies
# By
# prithivMLmods
# •
# 5 days ago
# •
# 16
# Nexus Shift: AI Generated Short Story
# By
# Duskfallcrew
# •
# 5 days ago
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Can't make imageToImage function work in javascript
# Beginners
# 1
# 9
# February 22, 2025
# Large LFS usage despite super_squash_history
# Beginners
# 2
# 7
# February 22, 2025
# Model loading gets stuck when calling "from_pretrained"
# 🤗Transformers
# 9
# 181
# February 22, 2025
# How to help in translating?
# Site Feedback
# 1
# 13
# February 21, 2025
# Running an LLM with high output quality locally
# Beginners
# 5
# 34
# February 22, 2025
# Agents Course Certification
# Spaces
# 9
# 122
# February 22, 2025
# Unable to run ai-agent
# Beginners
# 1
# 6
# February 22, 2025
# Invoke Assistant from HTTP
# Intermediate
# 1
# 5
# February 22, 2025
# How to Quantization the m2m-100 418M model？？
# 🤗Transformers
# 1
# 4
# February 22, 2025
# How to request mistral:7b-instruct to skip returning context?
# Models
# 3
# 9
# February 22, 2025
# Any AI model or tools can be used to generate Test Case and code quality scan
# Beginners
# 1
# 5
# February 22, 2025
# Paper author is incorrect
# Beginners
# 4
# 22
# February 21, 2025
# kohya_SS (Output Interpretation)
# Intermediate
# 8
# 14
# February 21, 2025
# How to access /tmp files
# Beginners
# 1
# 9
# February 21, 2025
# Streaming LangGraph with HuggingFacePipeline
# Beginners
# 1
# 10
# February 22, 2025
# 504 Gateway Time-out when uploading large dataset to enterprise organization
# 🤗Datasets
# 1
# 9
# February 21, 2025
# Should 24GB of VRAM be able to fine tune a 1B model?
# Beginners
# 7
# 113
# February 22, 2025
# Text Classification without context
# Beginners
# 3
# 35
# February 21, 2025
# Agent wont respond
# Beginners
# 2
# 14
# February 21, 2025
# /tmp files directory
# Beginners
# 0
# 7
# February 21, 2025
# Freeze Rt-detr backbone when fine tuning on custom dataset
# 🤗Transformers
# 3
# 7
# February 21, 2025
# Enterprise Analytics not working
# Site Feedback
# 3
# 17
# February 19, 2025
# Broken OpenAPI Spec
# Site Feedback
# 2
# 11
# February 21, 2025
# Evaluating my own model
# Intermediate
# 6
# 23
# February 21, 2025
# What is the most suitable padding strategy for PPOTrainer?
# 🤗Transformers
# 1
# 7
# February 20, 2025
# Loading in Float32 vs Float16 has very different speed
# 🤗Transformers
# 1
# 12
# February 20, 2025
# Potential bug in the rt-detr v2 fine tune script
# 🤗Transformers
# 1
# 58
# February 20, 2025
# File with .model extension
# Beginners
# 2
# 7
# February 20, 2025
# Scheduling failure error in HF
# Spaces
# 10
# 120
# February 20, 2025
# Can we use LLM model method or GenAI for lots of tabular information and get the insight of that
# 🤗Transformers
# 1
# 5
# February 21, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# Advanced Security
# Enterprise-grade security features
# GitHub Copilot
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 44.9k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 140k
# 28.1k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 27.6k
# 5.7k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 19.7k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 17.4k
# 1.7k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.4k
# 1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.8k
# 502
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 295 repositories
# open-r1
# Public
# Fully open reproduction of DeepSeek-R1
# huggingface/open-r1’s past year of commit activity
# Python
# 21,084
# Apache-2.0
# 1,844
# 152
# 31
# Updated
# Feb 22, 2025
# candle
# Public
# Minimalist ML framework for Rust
# huggingface/candle’s past year of commit activity
# Rust
# 16,640
# Apache-2.0
# 1,037
# 369
# (5 issues need help)
# 94
# Updated
# Feb 22, 2025
# blog
# Public
# Public repo for HF blog posts
# huggingface/blog’s past year of commit activity
# Jupyter Notebook
# 2,702
# 823
# 151
# (1 issue needs help)
# 68
# Updated
# Feb 22, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 27,625
# Apache-2.0
# 5,672
# 406
# (11 issues need help)
# 177
# Updated
# Feb 22, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 1,529
# MIT
# 307
# 93
# (5 issues need help)
# 56
# Updated
# Feb 22, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 41
# Apache-2.0
# 3
# 0
# 4
# Updated
# Feb 22, 2025
# pytorch-image-models
# Public
# The largest collection of PyTorch image encoders / backbones. Including train, eval, inference, export scripts, and pretrained weights -- ResNet, ResNeXT, EfficientNet, NFNet, Vision Transformer (ViT), MobileNetV4, MobileNet-V3 & V2, RegNet, DPN, CSPNet, Swin Transformer, MaxViT, CoAtNet, ConvNeXt, and more
# huggingface/pytorch-image-models’s past year of commit activity
# Python
# 33,241
# Apache-2.0
# 4,850
# 48
# (5 issues need help)
# 19
# Updated
# Feb 22, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 9,192
# Apache-2.0
# 988
# 118
# 111
# Updated
# Feb 21, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 139,937
# Apache-2.0
# 28,064
# 994
# (2 issues need help)
# 547
# Updated
# Feb 21, 2025
# lighteval
# Public
# Lighteval is your all-in-one toolkit for evaluating LLMs across multiple backends
# huggingface/lighteval’s past year of commit activity
# Python
# 1,188
# MIT
# 165
# 90
# (1 issue needs help)
# 23
# Updated
# Feb 21, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# x.com
# Webpage Contents:
#
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# LinkedIn and 3rd parties use essential and non-essential cookies to provide, secure, analyze and improve our Services, and to show you relevant ads (including
# professional and job ads
# ) on and off LinkedIn. Learn more in our
# Cookie Policy
# .
# Select Accept to consent or Reject to decline non-essential cookies for this use. You can update your choices at any time in your
# settings
# .
# Accept
# Reject
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 497 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# reposted this
# Gradio
# 56,726 followers
# 15h
# Edited
# Report this post
# Do you want to master building AI Agents?
#
# Join the 85,000+ learners in the
# Hugging Face
# agents-course and become an expert!
#
# 🔥 Trending smolagents framework is covered too—we’re thrilled by the community’s love for the smol library’s native agentic UI, built with
# Gradio
# ! 🧡
#
# 👉 agents-course by huggingface:
# https://lnkd.in/djF9bjm5
# 👉 open-DeepResearch using smolagents and its native gradio ui:
# https://lnkd.in/gbxcqfaH
# 👉 open-DeepResearch, powered by smolagents and
# Gradio.dev
# 👉 Learn all about smolagents!
# https://lnkd.in/dUC9W5VR
# 100
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian@🤗 | Championing Open Science & Machine Learning
# 1d
# Report this post
# Just hacked together a way to log TRL
# #GRPO
# training completions directly to a
# Hugging Face
# datasets repo.
#
# This allows you to:
# - Track rewards from multiple reward functions
# - Treat completions and rewards as a proper dataset for EDA
# - Share results for open science 🤓
#
# The current implementation is super hacky but only requires two extra parameters:
#
# ```
# training_args = GRPOConfig(
#     # other configs...
#     log_completions=True,
#     log_completions_hub_repo='your-username/repo-name'
# )
# ```
#
# Example completions log dataset:
# https://lnkd.in/eF2MKhXw
# Notebook:
# https://lnkd.in/eYRuTxPR
# I'm curious if other people find this interesting or useful for RLHF/GRPO research or if I'm the only weirdo who finds starting at GRPO completions interesting or useful.
# 42
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Miquel Àngel Farré
# ML @ Hugging Face
# 1d
# Report this post
# We've put video AI right on your iPhone! No cloud, no servers - everything happens right on your device 🤩
# 🎉 We are launching SmolVLM2 today!!
#
# This is what you can find in the release:
# - A 2.2B model that achieves top scores on Video-MME (the toughest video benchmark out there) in the 2B category. If that is not enough: it's way better at vision tasks than our previous SmolVLM. And yes, it runs on Google Colab! 🚀
# The two smallest video models ever:
#
# - A 500M model - That's how we got it running on phones! Want to build and test with us? Fill the form in our blog post and we will keep you in the loop.
#
# - A 256M model - because we love pushing boundaries perfect for experimenting and seeing just how far we can push this tech 🔬
#
# Oh, and we're working with the
# VideoLAN
# team to bring this to VLC! Imagine just asking your media player to find specific moments in your videos...
# We packed our blogpost with demos and code snippets. Find the link in the first comment.
# …more
# 1,103
# 69 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 2d
# Report this post
# We just shipped LoRA support in Lumina2 along with a new fine-tuning script as an example to follow 🔥
#
# Lumina2, being an Apache-2.0 model, holds tremendous promise for further widespread adaptation. I think the model packs quite a bit of performance for its size.
#
# I found its system prompting abilities to be particularly intriguing. For example, in the attached image, different system prompts for different environment settings have an impact without diluting the actual style of the LoRA.
#
# Get started with fine-tuning with this guide:
# https://lnkd.in/g3dbXDsw
# 171
# 9 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 56,726 followers
# 2d
# Report this post
# Many people find themselves exploring a Gradio app, often without even realizing it! 👀
# 46
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 891,042 followers
# 2d
# Report this post
# A highly requested feature from Gradio developers 🔥 is on its way in upcoming releases.
# Gradio
# 56,726 followers
# 2d
# 🚀 Performance Breakthrough: Instant UI Updates
# No server roundtrips; UI updates within your browser.
#
# Watch the video to understand Before vs After with a simple Todo app.
#
# 🤩 Key Benefits:
# - Instant component updates
# - Better user experience
# - No additional Javascript to be written
#
# 🚀 Perfect for:
# - Dynamic UI elements
# - Real-time updates
#
# This maintains Gradio's Python-first approach and addresses one of the most requested features from our developer community. Coming to you in our next release 🥳
# 23
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 2d
# Report this post
# Google
# just released PaliGemma 2 Mix: new versatile instruction vision language models 🔥 learn more in comments 💬
#
# > Three new models: 3B, 10B, 28B with res 224, 448 💙
# > Can do vision language tasks with open-ended prompts, understand documents, and segment or detect anything 🤯
# …more
# 1,024
# 27 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 56,726 followers
# 2d
# Report this post
# Every minute of boilerplate code reduces time for innovation
# That's why we've built Gradio Sketch🤯
#
# Visually design your AI interfaces:
# ↓ Add components
# ↓ Configure settings
# ↓ Preview in real-time
# ↓ Get production-ready code in seconds
#
# The future of AI app development should be visual!
# And it starts with: `gradio sketch testdotpy`
#
# Who else is tired of writing repetitive interface code for their AI apps?
# …more
# 320
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Joffrey THOMAS
# Machine Learning Engineer - Hugging Face 🤗
# 3d
# Edited
# Report this post
# 🚀 Bonus Unit Alert! 🚀
# 𝐅𝐢𝐧𝐞-𝐭𝐮𝐧𝐢𝐧𝐠 𝐲𝐨𝐮𝐫 𝐦𝐨𝐝𝐞𝐥 𝐟𝐨𝐫 𝐅𝐮𝐧𝐜𝐭𝐢𝐨𝐧-𝐂𝐚𝐥𝐥𝐢𝐧𝐠 𝐢𝐬 𝐨𝐮𝐭 !
#
# 𝐅𝐮𝐧𝐜𝐭𝐢𝐨𝐧-𝐂𝐚𝐥𝐥𝐢𝐧𝐠 has been introduced by OpenAI in GPT-4. It's a training technique that allocate new special tokens and messages roles to your model.
#
# 🔗:
# https://lnkd.in/ebsRZqNE
# What you'll learn :
# 1️⃣ 𝐅𝐮𝐧𝐜𝐭𝐢𝐨𝐧-𝐜𝐚𝐥𝐥𝐢𝐧𝐠 : What is it, how does it modify the conversations with your AI.
# 2️⃣ 𝐇𝐨𝐰 𝐭𝐨 𝐦𝐚𝐤𝐞 𝐲𝐨𝐮𝐫 𝐦𝐨𝐝𝐞𝐥 "𝐭𝐡𝐢𝐧𝐤" : The powerful recipe behind the success of DeepSeek AI.
# 3️⃣ 𝐅𝐢𝐧𝐞-𝐓𝐮𝐧𝐢𝐧𝐠 (𝐒𝐅𝐓): Learn LoRA, a powerful technique to fine-tune a model through adapters for a fraction of the cost of the full fine-tuning.
# 769
# 20 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 4d
# Edited
# Report this post
# Inference-time scaling meets Flux.1-Dev (and others) 🔥
#
# Presenting a simple re-implementation of "Inference-time scaling diffusion models beyond denoising steps" by
# Willis (Nanye) Ma
# et al.
#
# I did the simplest random search strategy, but results can potentially be improved with better-guided search methods.
#
# Supports Gemini 2 Flash & Qwen2.5 as verifiers for "LLMGrading" 🤗
#
# The steps are simple:
#
# For each round:
# 1> Starting by sampling 2 starting noises with different seeds.
# 2> Score the generations w.r.t a metric.
# 3> Obtain the best generation from the current round.
#
# If you have more compute budget, go to the next search round. Scale the noise pool (2 ** search_round) and repeat 1 - 3.
#
# This constitutes the random search method as done in the paper by
# Google DeepMind
# .
#
# Code, more results, and a bunch of other stuff are in the repository. Check it out here:
# https://lnkd.in/gPRDz7KB
# 🤗
#
# Thanks to
# Willis
# for all the help in getting this shipped!
# 172
# 5 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# Perplexity
# Software Development
# San Francisco, California
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 7 total rounds
# Last Round
# Series D
# Feb 16, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# "You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nperplexity-ai/r1-1776\nUpdated\n3 days ago\n•\n7.03k\n•\n1.38k\ndeepseek-ai/DeepSeek-R1\nUpdated\n13 days ago\n•\n4.4M\n•\n9.9k\nmicrosoft/OmniParser-v2.0\nUpdated\n4 days ago\n•\n4.2k\n•\n834\nstepfun-ai/Step-Audio-Chat\nUpdated\n5 days ago\n•\n609\n•\n335\nstepfun-ai/stepvideo-t2v\nUpdated\n3 days ago\n•\n944\n•\n281\nBrowse 1M+ models\nSpaces\nRunning\n1.25k\n1.25k\nThe Ultra-Scale Playbook\n🌌\nThe ultimate guide to training LLM on large GPU Clusters\nRunning\non\nZero\n645\n645\nLuminaBrush\n📈\nExecute environment script\nRunning\non\nZero\n271\n271\nOmniParser V2\n🏢\nOmniParser, turn your LLM into GUI agent\nRunning\non\nZero\n7.34k\n7.34k\nFLUX.1 [dev]\n🖥\nGenerate images from text prompts\nRunning\non\nCPU Upgrade\n518\n518\nOpen Deep-Research\n🏆\nOpenAI's Deep Research, but open\nBrowse 400k+ applications\nDatasets\nCongliu/Chinese-DeepSeek-R1-Distill-data-110k\nUpdated\n1 day ago\n•\n1.95k\n•\n301\nfacebook/natural_reasoning\nUpdated\n1 day ago\n•\n804\n•\n134\nopen-r1/OpenR1-Math-220k\nUpdated\n4 days ago\n•\n18.3k\n•\n387\nopen-thoughts/OpenThoughts-114k\nUpdated\n2 days ago\n•\n101k\n•\n576\nSakanaAI/AI-CUDA-Engineer-Archive\nUpdated\n2 days ago\n•\n4.62k\n•\n75\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n389 models\n•\n2.39k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.06k models\n•\n4.68k followers\nAmazon Web Services\ncompany\n•\n20 models\n•\n2.75k followers\nGoogle\ncompany\n•\n959 models\n•\n8.04k followers\nIntel\ncompany\n•\n218 models\n•\n2.27k followers\nMicrosoft\ncompany\n•\n356 models\n•\n8.98k followers\nGrammarly\ncompany\n•\n10 models\n•\n126 followers\nWriter\nEnterprise\ncompany\n•\n17 models\n•\n241 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n139,937\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n27,625\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,121\nSafe way to store/distribute neural network weights\nHub Python Library\n2,356\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,399\nFast tokenizers optimized for research & production\nTRL\n11,885\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,020\nState-of-the-art ML running directly in your browser\nsmolagents\n11,436\nSmol library to build great agents in Python\nPEFT\n17,423\nParameter-efficient finetuning for large language models\nDatasets\n19,667\nAccess &  ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.com/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Company Brochure
#
# ## About Us
# Hugging Face is at the forefront of the AI revolution, committed to building an open, collaborative platform that empowers the machine learning (ML) community. We provide tools and resources that allow users to create, discover, and collaborate on models, datasets, and applications. With over **1 million models** and **250,000 datasets**, we are the definitive hub for AI innovation.
#
# ### Mission Statement:
# **"The AI community building the future."**
#
# ---
#
# ## Our Offerings
# ### Key Features:
# - **Models**: Collaborate with over 1M models including those from notable organizations like Amazon, Microsoft, and Google.
# - **Datasets**: Access a rich collection of more than 250k datasets to fuel your AI projects.
# - **Spaces**: Share and run your applications in an interactive environment.
# - **Enterprise Solutions**: Tailored features for organizations with a strong focus on security, control, and dedicated support.
#
# ---
#
# ## Who We Serve
# Hugging Face is trusted by **more than 50,000 organizations**, including top-tier players such as:
# - **Ai2**
# - **Meta**
# - **Amazon Web Services**
# - **Intel**
# - **Grammarly**
#
# Our platform provides the tools necessary for companies and researchers to leverage machine learning for diverse applications.
#
# ---
#
# ## Company Culture
# We foster a **collaborative and innovative environment** that encourages continuous learning and sharing among team members. Hugging Face is built on the principles of **open source**, transparency, and community engagement. With a team of **210+** dedicated individuals, we thrive on pushing the boundaries of what's possible in AI and ML.
#
# ### Values:
# - **Inclusivity & Diversity**: We believe that diverse perspectives foster innovation.
# - **Community-Driven**: Contributions from users across the globe shape our offerings.
# - **Learning & Growth**: We support our team's professional development and learning journeys.
#
# ---
#
# ## Careers at Hugging Face
# Join us in our mission to democratize AI! We are always on the lookout for talented individuals who are passionate about ML and AI. Explore a variety of career opportunities ranging from engineering to community management.
#
# - **Current Openings**: Visit [Hugging Face Careers](https://huggingface.co/jobs) to find positions suited for you.
# - **Benefits**: We offer competitive salaries, flexible working hours, and a vibrant team culture.
#
# ---
#
# ## Connect with Us
# Stay up to date with our latest developments and community activities:
# - **Website**: [Hugging Face](https://huggingface.co)
# - **GitHub**: [Hugging Face GitHub](https://github.com/huggingface)
# - **Twitter**: [@huggingface](https://twitter.com/huggingface)
# - **Join our Discord**: Get involved and bring your ideas!
#
# ---
#
# At Hugging Face, we are not just building tools; we are creating a community structured around innovation, collaboration, and shared success in AI. Discover the future with us!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
#
# ### The AI Community Building the Future
#
# Hugging Face is at the forefront of the artificial intelligence revolution. Our platform serves as a collaborative space for the machine learning community, allowing users to create, discover, and contribute unparalleled models, datasets, and applications.
#
# **Explore Our Offerings:**
# - **Models:** Access over 1 million models across various domains.
# - **Datasets:** Browse through 250k+ datasets to enhance your projects.
# - **Spaces:** Run and showcase your innovative AI applications seamlessly.
#
# ---
#
# ## Our Commitment to Collaboration
#
# At Hugging Face, we believe in the power of community. We provide a space for ML professionals, researchers, and enthusiasts to share their insights and collaborate on projects. Our open-source ecosystem empowers users with tools like Transformers, Diffusers, Tokenizers, and more, supporting diverse tasks in machine learning.
#
# ### Join our community, partner with top organizations:
# Some of the notable organizations using Hugging Face’s platform include:
# - **Microsoft**
# - **Google**
# - **Amazon Web Services**
# - **Meta**
# - **Intel**
#
# With over 50,000 organizations leveraging our technology, the possibilities are endless.
#
# ---
#
# ## Cultivating a Unique Company Culture
#
# ### We Foster Innovation
#
# Hugging Face not only encourages collaboration but thrives on innovation. Our work culture supports continual learning and experimentation. Employees are inspired to explore new ideas, making breakthroughs in AI possible.
#
# ### Values and Inclusivity
#
# We value diversity and inclusivity, celebrating the unique perspectives that each member brings to the team. Our engagement in various community initiatives aims to promote learning and access in AI fields for everyone.
#
# ---
#
# ## Careers at Hugging Face
#
# Hugging Face is constantly seeking talented individuals to join our team. As a growing company, we offer various career opportunities in machine learning, software development, product management, and more.
#
# ### Why Work with Us?
# - **Impact:** Your work will directly contribute to the AI landscape.
# - **Growth:** We support and invest in your personal and professional development.
# - **Collaboration:** Work alongside industry leaders and pioneers in the AI community.
#
# Interested in joining us? Check out our [Careers page](#) for current job openings.
#
# ---
#
# ## Get Involved
#
# Whether you’re a researcher, developer, business, or simply interested in AI, Hugging Face welcomes you to join our community. Explore applications, contribute to open-source projects, or engage in discussions on machine learning.
#
# ### Let’s Build the Future of AI Together!
#
# For more information:
# - Visit our website: [huggingface.co](https://huggingface.co)
# - Connect on [Twitter](https://twitter.com/huggingface)
# - Join the conversation on [Discord](https://discord.gg/huggingface)
#
# Hugging Face – Together, we’re building the future of AI!

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company blog', 'url': 'https://huggingface.co/blog'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'community discussion', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face!
# **The AI community building the future.** Hugging Face is the premier platform for collaboration in the machine learning community, providing tools and solutions for models, datasets, and applications. Join us in exploring and advancing the field of artificial intelligence.
#
# ---
#
# ## Company Overview
# - **Founded**: Established with the vision to democratize AI and make it accessible to all.
# - **Mission**: To foster a vibrant community that collaborates on building state-of-the-art machine learning models and applications.
#
# ---
#
# ## Our Offerings
#
# ### Models
# Hugging Face hosts over **1 million models** across various tasks including text, image, video, and audio processing. Our community shares cutting-edge models for all to access and implement.
#
# ### Datasets
# Explore and contribute to **250,000+ datasets**. Users can access a rich repository of data essential for training and developing AI models.
#
# ### Spaces
# Hugging Face provides a collaboration platform to host and manage applications with ease. With **thousands of active applications,** you can experiment, build, and share your work.
#
# ### Enterprise Solutions
# For organizations looking for robust support:
# - Tailored enterprise plans starting from **$20/user/month**
# - Advanced security features and dedicated support
# - Over **50,000+ organizations** are already part of our community.
#
# ---
#
# ## Customers
# Our diverse customer base includes renowned companies and organizations:
# - **Microsoft**
# - **Google**
# - **Amazon Web Services**
# - **Intel**
# - **Grammarly**
# - **Meta** (formerly Facebook)
#
# ---
#
# ## Company Culture
# Hugging Face embraces a culture of **open-source collaboration** and **innovation**. We believe in the power of community and provide our team members with an environment that promotes:
# - Continuous learning and experimentation
# - Flexibility and creativity in problem-solving
# - An open and inclusive atmosphere where every voice matters
#
# ---
#
# ## Career Opportunities
# Join us on our mission! We are continuously looking for talent in various domains:
# - **Machine Learning Engineers**
# - **Data Scientists**
# - **Software Developers**
# - **Community Managers**
#
# At Hugging Face, you will be part of a collaborative team that is passionate about AI and shaping the future of technology.
#
# ---
#
# ## Get Involved
# Whether you’re a developer, a researcher, or a business leader, Hugging Face offers tools and resources to help you innovate.
# - **Join the Community**: Sign up on our platform to start collaborating.
# - **Explore**: Check our documentation and community forum to learn more.
# - **Follow Us**: Stay updated on our activities through GitHub, Twitter, LinkedIn, and Discord.
#
# ---
#
# ### Contact Us
# - **Website**: [huggingface.co](https://huggingface.co)
# - **Social Media**: Connect with us on social platforms to get the latest updates.
#
# Join Hugging Face and be a part of revolutionizing AI today!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
